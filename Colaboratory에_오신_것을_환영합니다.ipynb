# %% [markdown]
# <a href="https://colab.research.google.com/github/fine4546/AI/blob/master/Colaboratory%EC%97%90_%EC%98%A4%EC%8B%A0_%EA%B2%83%EC%9D%84_%ED%99%98%EC%98%81%ED%95%A9%EB%8B%88%EB%8B%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Colaboratory란?</h1>
#
# Colaboratory&#40;또는 줄여서 'Colab'&#41;를 사용하면 브라우저에서 Python을 작성하고 실행할 수 있습니다.
# - 구성 필요 없음
# - GPU 무료 액세스
# - 간편한 공유
#
# <strong>학생</strong>이든, <strong>데이터 과학자</strong>든, <strong>AI 연구원</strong>이든 Colab으로 업무를 더욱 간편하게 처리할 수 있습니다. <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Colab 소개 영상</a>에서 자세한 내용을 확인하거나 아래에서 시작해 보세요.

# %% [markdown]
# ## <strong>시작하기</strong>
#
# 지금 읽고 계신 문서는 정적 웹페이지가 아니라 코드를 작성하고 실행할 수 있는 대화형 환경인 <strong>Colab 메모장</strong>입니다.
#
# 예를 들어 다음은 값을 계산하여 변수로 저장하고 결과를 출력하는 간단한 Python 스크립트가 포함된 <strong>코드 셀</strong>입니다.

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# 위 셀의 코드를 실행하려면 셀을 클릭하여 선택한 후 코드 왼쪽의 실행 버튼을 누르거나 단축키 'Command/Ctrl+Enter'를 사용하세요. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.
#
# 특정 셀에서 정의한 변수를 나중에 다른 셀에서 사용할 수 있습니다.

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab 메모장을 사용하면 <strong>실행 코드</strong>와 <strong>서식 있는 텍스트</strong>를 <strong>이미지</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> 등과 함께 하나의 문서로 통합할 수 있습니다. Colab 메모장을 만들면 Google 드라이브 계정에 저장됩니다. Colab 메모장을 간편하게 공유하여 동료나 친구들이 댓글을 달거나 수정하도록 할 수 있습니다. 자세히 알아보려면 <a href="/notebooks/basic_features_overview.ipynb">Colab 개요</a>를 참조하세요. 새 Colab 메모장을 만들려면 위의 파일 메뉴를 사용하거나 다음 링크로 이동하세요. <a href="http://colab.research.google.com#create=true">새 Colab 메모장 만들기</a>
#
# Colab 메모장은 Colab에서 호스팅하는 Jupyter 메모장입니다. Jupyter 프로젝트에 관해 자세히 알아보려면 <a href="https://www.jupyter.org">jupyter.org</a>를 참조하세요.

# %% [markdown]
# ## 데이터 과학
#
# Colab을 통해 인기 있는 Python 라이브러리를 최대한 활용하여 데이터를 분석하고 시각화할 수 있습니다. 아래 코드 셀에서는 <strong>numpy</strong>를 사용하여 임의의 데이터를 생성하고 <strong>matplotlib</strong>으로 이를 시각화합니다. 셀을 클릭하면 코드 수정을 바로 시작할 수 있습니다.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# Google 드라이브 계정에서 스프레드시트를 비롯한 데이터를 Colab 메모장으로 가져오거나 GitHub 등의 여러 다른 소스에서 데이터를 가져올 수 있습니다. Colab을 데이터 과학에 활용하는 방법과 데이터 가져오기에 관해 자세히 알아보려면 <a href="#working-with-data">데이터 사용하기</a> 아래 링크를 참조하세요.

# %% [markdown]
# ## 머신러닝
#
# Colab을 사용하면 <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">코드 몇 줄만으로</a> 이미지 데이터세트를 가져오고, 이 데이터세트로 이미지 분류기를 학습시키며, 모델을 평가할 수 있습니다. Colab 메모장은 Google 클라우드 서버에서 코드를 실행하므로 사용 중인 컴퓨터 성능과 관계없이 <a href="#using-accelerated-hardware">GPU 및 TPU</a>를 포함한 Google 하드웨어 성능을 활용할 수 있습니다. 브라우저만 있으면 사용 가능합니다.

# %% [markdown]
# Colab은 다음과 같은 분야의 머신러닝 커뮤니티에서 널리 쓰이고 있습니다.
# - TensorFlow 시작하기
# - 신경망 개발 및 학습하기
# - TPU로 실험하기
# - AI 연구 보급
# - 가이드 만들기
#
# 머신러닝 적용 사례를 보여 주는 Colab 메모장 샘플을 확인하려면 아래 <a href="#machine-learning-examples">머신러닝 예제</a>를 참조하세요.

# %% [markdown]
# ## 추가 리소스
#
# ### Colab에서 메모장 사용하기
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
# - [라이브러리 가져오기 및 종속 항목 설치하기](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub에서 노트 저장 및 로드하기](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [대화형 양식](/notebooks/forms.ipynb)
# - [대화형 위젯](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [Colab의 TensorFlow 2](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### 데이터로 작업하기
# - [데이터 로드: 드라이브, 스프레드시트, Google Cloud Storage](/notebooks/io.ipynb)
# - [차트: 데이터 시각화하기](/notebooks/charts.ipynb)
# - [BigQuery 시작하기](/notebooks/bigquery.ipynb)
#
# ### 머신러닝 단기집중과정
# 다음은 Google 온라인 머신러닝 과정에서 가져온 일부 노트입니다. <a href="https://developers.google.com/machine-learning/crash-course/">전체 과정 웹사이트</a>에서 자세한 내용을 확인하세요.
# - [Pandas 소개](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [TensorFlow 개념](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [TensorFlow 첫걸음](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [신경망 소개](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [희소 데이터 및 임베딩 소개](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# <a name="using-accelerated-hardware"></a>
# ### 가속 하드웨어 사용하기
# - [GPU를 사용한 TensorFlow](/notebooks/gpu.ipynb)
# - [TPU를 사용한 TensorFlow](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## 머신러닝 예제
#
# Colaboratory 덕분에 가능해진 대화형 머신러닝 분석의 예시를 자세히 살펴보려면 <a href="https://research.google.com/seedbank/">Seedbank</a> 프로젝트를 확인하세요.
#
# 일부 추천 예시는 다음과 같습니다.
#
# - <a href="https://research.google.com/seedbank/seed/neural_style_transfer_with_tfkeras">신경망 스타일 이전</a>: 딥 러닝을 사용하여 이미지 간에 스타일을 이전합니다.
# - <a href="https://research.google.com/seedbank/seed/ez_nsynth">EZ NSynth</a>: WaveNet 자동 인코더로 오디오를 합성합니다.
# - <a href="https://research.google.com/seedbank/seed/fashion_mnist_with_keras_and_tpus">Keras 및 TPU를 사용한 Fashion MNIST</a>: 딥 러닝으로 패션 관련 이미지를 분류합니다.
# - <a href="https://research.google.com/seedbank/seed/deepdream">DeepDream</a>: 내 사진으로 DeepDream 이미지를 만듭니다.
# - <a href="https://research.google.com/seedbank/seed/convolutional_vae">컨볼루션 VAE</a>: 손으로 쓴 숫자의 생성 모델을 만듭니다.

# %% [markdown]
# Do it Running!!

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

plt.plot([1,2,3,4,5],[1,4,9,16,25])

plt.show()
print(np.__version__)
print('tensorflow :',tf.__version__)
# Out:
# 1.17.5
# tensorflow : 1.15.0

# %%
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist/data/", one_hot=True)

#############
# 신경망 모델 구성
##############
X = tf.placeholder(tf.float32, [None, 784])
Y = tf.placeholder(tf.float32, [None, 10])

W1 = tf.Variable(tf.random_normal([784,256], stddev = 0.01))
L1 = tf.nn.relu(tf.matmul(X,W1))

W2 = tf.Variable(tf.random_normal([256,256], stddev = 0.01))
L2 = tf.nn.relu(tf.matmul(L1,W2))

W3 = tf.Variable(tf.random_normal([256,10], stddev = 0.01))
model = tf.matmul(L2,W3)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=Y))
optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)

############
#  신경망 모델 학습
############
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

batch_size = 100
total_batch = int(mnist.train.num_examples / batch_size)

for epoch in range(15):
  total_cost = 0

  for i in range(total_batch):
    batch_xs, batch_ys = mnist.train.next_batch(batch_size)

    _, cost_val = sess.run([optimizer, cost],
        feed_dict = {X: batch_xs, Y:batch_ys})
    total_cost+=cost_val

    print('Epoch:', '%04d' % (epoch + 1),'Avg. cost =', '{:3f}'.format(total_cost / total_batch))
    
    print('최적화 완료')

##########
# 결과 확인
##########

is_correct = tf.equal(tf.argmax(model, 1), tf.agrmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(is_correct, tf_float32))
print('정확도:', sess.run(accuracy,
                       feed_dict={X: mnist.test.images,
                                  Y: mnist.test.images}))
# Out:
# Extracting ./mnist/data/train-images-idx3-ubyte.gz
# Extracting ./mnist/data/train-labels-idx1-ubyte.gz
# Extracting ./mnist/data/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/data/t10k-labels-idx1-ubyte.gz
# Epoch: 0001 Avg. cost = 0.004187
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.008368
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.012540
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.016704
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.020844
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.024954
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.029029
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.033053
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.037020
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.040922
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.044772
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.048541
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.052190
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.055750
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.059095
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.062367
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.065341
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.068245
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.070913
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.073621
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.076075
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.078622
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.080694
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.082929
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.084946
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.086999
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.089122
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.090920
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.092913
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.094587
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.096296
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.098036
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.099840
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.101478
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.103049
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.104786
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.106238
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.107405
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.109056
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.110647
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.112028
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.113619
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.115011
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.116681
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.118466
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.120019
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.121187
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.122494
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.123894
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.125150
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.126323
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.127504
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.128520
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.129669
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.130781
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.131902
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.133283
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.134521
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.135687
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.136606
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.137543
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.138623
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.139816
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.140815
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.142153
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.143131
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.144052
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.145135
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.146094
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.147026
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.148152
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.149329
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.150178
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.151276
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.152304
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.153494
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.154592
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.155782
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.156589
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.157824
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.158592
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.159355
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.160275
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.161428
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.162278
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.162996
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.164047
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.164999
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.165772
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.166842
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.168023
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.168901
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.169751
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.170673
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.171355
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.172248
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.172972
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.173709
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.174541
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.175321
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.176125
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.176949
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.177705
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.178266
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.179072
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.180207
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.181260
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.182037
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.182735
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.183370
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.184021
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.184648
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.185446
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.186295
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.186970
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.187615
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.188430
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.189098
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.189813
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.190356
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.191020
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.191847
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.192375
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.193229
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.194008
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.195034
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.195821
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.196312
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.197240
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.198035
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.198527
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.199596
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.200181
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.200654
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.201265
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.201974
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.202495
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.203158
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.203797
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.204432
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.205331
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.205814
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.206558
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.207137
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.207719
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.208185
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.208796
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.209645
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.210305
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.211059
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.211960
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.212616
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.213245
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.213737
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.214249
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.214754
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.215525
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.216449
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.217162
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.217665
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.218482
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.219282
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.219850
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.220208
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.221041
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.221491
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.222287
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.222795
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.223330
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.223938
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.224509
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.225155
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.226120
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.227000
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.228093
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.228643
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.229231
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.229787
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.230727
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.231648
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.232435
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.232850
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.233761
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.234510
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.235241
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.235790
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.236394
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.236888
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.237334
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.238056
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.238694
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.239176
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.239798
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.240260
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.241139
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.241776
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.242264
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.242896
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.243917
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.244427
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.245131
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.245816
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.246358
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.246808
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.247508
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.247918
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.248760
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.249316
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.249669
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.250330
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.250858
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.251421
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.252001
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.252639
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.253038
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.253539
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.254031
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.254607
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.255278
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.256023
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.256563
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.257264
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.257785
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.258463
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.259108
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.259800
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.260193
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.261050
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.261792
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.262653
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.262985
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.263373
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.264511
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.264989
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.265613
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.266024
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.266562
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.267388
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.267928
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.268445
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.269040
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.269590
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.270726
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.271100
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.271506
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.272237
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.272771
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.273202
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.274005
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.274630
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.275479
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.276210
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.276726
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.277118
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.277416
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.278097
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.278641
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.279246
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.279672
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.280395
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.281035
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.281511
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.282304
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.282549
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.283136
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.283770
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.284363
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.285060
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.285426
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.285947
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.286368
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.286950
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.287328
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.288076
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.288849
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.289718
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.290167
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.290463
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.291100
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.291581
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.292009
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.292615
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.293065
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.293497
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.293896
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.294383
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.295014
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.295371
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.295837
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.296225
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.296599
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.297010
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.297554
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.298090
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.298468
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.298870
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.299201
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.299547
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.300337
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.300875
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.301216
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.301675
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.302112
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.302667
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.303056
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.303462
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.303683
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.304052
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.304721
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.305161
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.305567
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.305853
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.306124
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.306819
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.307349
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.307903
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.308585
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.309084
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.309611
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.309919
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.310359
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.310921
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.311181
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.311563
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.311797
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.312386
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.313062
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.313803
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.314515
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.315191
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.315687
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.316084
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.316826
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.317351
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.317791
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.318114
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.318723
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.319190
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.319723
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.320240
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.321086
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.321234
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.321963
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.322603
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.323022
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.323225
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.323591
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.324187
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.324628
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.325233
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.325662
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.326212
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.326659
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.326942
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.327307
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.327855
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.328193
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.328677
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.329109
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.329626
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.330311
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.330676
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.331034
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.331652
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.332025
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.332386
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.332920
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.333283
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.333972
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.334292
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.334755
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.335282
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.335815
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.336330
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.336912
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.337179
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.337412
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.337804
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.338061
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.338325
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.338551
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.338846
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.339378
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.339831
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.340354
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.340868
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.341329
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.341949
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.342793
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.343352
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.343576
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.343931
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.344222
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.344705
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.345062
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.345563
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.345950
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.346311
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.346967
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.347524
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.347740
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.348040
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.348591
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.348892
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.349362
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.349762
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.350270
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.350751
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.351147
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.351655
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.352077
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.352404
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.352744
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.353053
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.353589
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.354099
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.354695
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.355298
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.355670
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.356197
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.356620
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.357181
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.357613
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.357874
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.358280
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.358499
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.359161
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.359624
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.360114
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.360579
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.361036
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.361559
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.361963
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.362319
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.362657
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.362977
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.363612
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.364175
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.364661
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.365128
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.365515
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.365787
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.366138
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.366516
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.366971
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.367413
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.367576
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.368148
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.368754
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.369174
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.369353
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.369807
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.370278
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.370575
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.371089
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.371475
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.371856
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.372325
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.372758
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.373014
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.373548
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.373973
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.374200
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.374670
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.374944
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.375425
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.375688
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.376145
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.376474
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.377020
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.377299
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.377655
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.378259
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.378457
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.378731
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.378921
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.379225
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.379551
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.379870
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.380270
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.380720
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.381014
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.381192
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.381644
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.381980
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.382629
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.383052
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.383829
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.384192
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.384380
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.384939
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.385178
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.385819
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.386088
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.386446
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.386934
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.387307
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.387559
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.387955
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.388351
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.388668
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.388906
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.389342
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.389736
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.390421
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.390747
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.391128
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.391399
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.391691
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.392022
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.392446
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.392870
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.393074
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.393509
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.393870
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.394199
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.394498
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.394920
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.395161
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.395463
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.395729
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.396082
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.396533
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.397091
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.397337
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.397744
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.397986
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.398416
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.398870
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.399490
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.399995
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.400252
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.400505
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.400710
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.400933
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.401476
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.401935
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.402149
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.402619
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.403277
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.403629
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.404089
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.404399
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.404936
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.405305
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.405876
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.406107
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.406465
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.406840
# 최적화 완료
# Epoch: 0001 Avg. cost = 0.407286
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.000306
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.000806
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.001061
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.001378
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.001841
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.002030
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.002314
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.002554
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.003136
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.003365
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.003554
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.003931
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.004250
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.004630
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.005026
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.005223
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.005645
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.005931
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.006230
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.006665
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.006886
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.007075
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.007319
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.007878
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.008173
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.008407
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.008639
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.009039
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.009256
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.009787
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.010092
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.010554
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.010831
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.011076
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.011332
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.011558
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.011741
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.012025
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.012342
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.012593
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.013001
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.013270
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.013680
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.014026
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.014323
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.014937
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.015124
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.015254
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.015621
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.015899
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.016284
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.016741
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.017040
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.017326
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.017649
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.017746
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.017939
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.018203
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.018679
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.019068
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.019449
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.019778
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.020262
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.020455
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.020825
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.021074
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.021420
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.021558
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.022089
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.022410
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.023238
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.023452
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.023570
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.023959
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.024167
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.024332
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.024520
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.024961
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.025177
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.025597
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.025746
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.025977
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.026102
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.026390
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.026578
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.026842
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.026993
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.027412
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.027664
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.027964
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.028346
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.028619
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.028886
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.029424
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.029684
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.029971
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.030351
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.030602
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.031022
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.031245
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.031683
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.031998
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.032239
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.032711
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.032977
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.033255
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.033488
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.033872
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.034042
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.034392
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.034635
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.034817
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.035296
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.035529
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.035926
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.036155
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.036406
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.036799
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.037332
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.037789
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.038225
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.038637
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.038979
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.039448
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.039858
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.040008
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.040559
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.040990
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.041341
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.041670
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.041955
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.042267
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.042574
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.042773
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.043251
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.043703
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.043918
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.044328
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.044678
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.044860
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.045068
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.045425
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.045605
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.045758
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.046147
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.046388
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.046758
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.047111
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.047458
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.047728
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.048020
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.048230
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.048582
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.048840
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.049060
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.049297
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.049435
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.049563
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.049818
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.050057
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.050235
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.050400
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.050702
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.051207
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.051373
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.051550
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.051809
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.052148
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.052636
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.053122
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.053236
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.053463
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.053717
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.053969
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.054388
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.054698
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.054908
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.055420
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.055513
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.055862
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.055966
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.056232
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.056475
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.056730
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.056994
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.057354
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.057622
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.057884
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.058322
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.058499
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.058773
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.058894
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.059157
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.059346
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.059652
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.059786
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.060153
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.060398
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.060619
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.060780
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.061189
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.061521
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.061837
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.062135
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.062334
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.062610
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.062825
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.063256
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.063537
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.063846
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.064041
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.064442
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.064724
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.065136
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.065827
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.066104
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.066610
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.066767
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.067403
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.067632
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.067915
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.068051
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.068447
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.068708
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.068858
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.069119
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.069663
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.069938
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.070094
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.070403
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.070645
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.071039
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.071398
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.071574
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.072062
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.072399
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.072706
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.073158
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.073452
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.073827
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.074313
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.074739
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.075051
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.075158
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.075307
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.075761
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.075864
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.076116
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.076364
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.076528
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.076674
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.077067
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.077249
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.077470
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.077664
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.077837
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.078046
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.078485
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.078736
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.078968
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.079393
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.079692
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.079888
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.080084
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.080436
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.080779
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.080970
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.081299
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.081648
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.082067
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.082190
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.082460
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.082841
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.083065
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.083343
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.083493
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.083658
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.083952
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.084192
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.084520
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.085006
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.085190
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.085509
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.085774
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.086067
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.086193
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.086464
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.086654
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.086985
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.087216
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.087588
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.087979
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.088249
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.088453
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.088600
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.088736
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.088999
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.089395
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.089863
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.090013
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.090353
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.090553
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.090835
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.090998
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.091219
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.091480
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.091718
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.092001
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.092317
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.092639
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.092960
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.093298
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.093700
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.093970
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.094106
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.094402
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.094755
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.094965
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.095166
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.095506
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.095796
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096127
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096283
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096474
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096647
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096762
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.096880
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.097232
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.097602
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.097744
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.098006
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.098412
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.098738
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.099045
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.099350
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.099730
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.100018
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.100308
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.100818
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.100944
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.100993
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.101468
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.101737
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.102001
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.102344
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.102675
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.102910
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.103184
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.103512
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.103748
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.104082
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.104339
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.104749
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.104980
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.105130
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.105481
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.105684
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.105883
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.106134
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.106289
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.106590
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.106702
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.106912
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.107152
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.107739
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.107927
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.108045
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.108130
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.108248
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.108450
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.108742
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.109124
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.109321
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.109543
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.109904
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.110009
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.110170
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.110290
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.110562
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.110804
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.111119
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.111347
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.111641
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.112092
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.112288
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.112678
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.112834
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.112929
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.113209
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.113538
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.113801
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.114093
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.114413
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.114667
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.114748
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.114978
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.115211
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.115534
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.115783
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.116322
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.116641
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.116832
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.117197
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.117376
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.117515
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.117785
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.117952
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.118151
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.118697
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.118911
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.119052
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.119315
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.119658
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.119814
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.119959
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.120189
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.120353
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.120566
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.120858
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.121110
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.121265
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.121744
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.121939
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.122229
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.122571
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.122716
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.122948
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.123123
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.123216
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.123360
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.123851
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.124132
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.124250
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.124598
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.124870
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.125278
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.125531
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.125721
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.125982
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.126236
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.126353
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.126564
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.126790
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.126986
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.127166
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.127768
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.128077
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.128244
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.128532
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.128609
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.128958
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.129180
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.129374
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.129608
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130022
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130165
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130424
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130625
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130773
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.130958
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.131295
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.131399
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.131594
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.131702
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.131817
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.132311
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.132421
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.132694
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.133283
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.133805
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.134036
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.134220
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.134465
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.134657
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.134857
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.135180
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.135477
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.135871
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.136094
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.136432
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.136629
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137001
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137232
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137379
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137464
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137547
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137838
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.137948
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138214
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138304
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138407
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138577
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138648
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.138954
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.139200
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.139395
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.139581
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.139824
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.140098
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.140499
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.140544
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.140986
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.141222
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.141408
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.141762
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.141964
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.142311
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.142653
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.142914
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.143113
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.143432
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.143600
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.143883
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.144239
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.144429
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.144588
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.144714
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.145051
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.145364
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.145583
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.145769
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146029
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146213
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146404
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146658
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146893
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.146952
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.147109
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.147310
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.147519
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.147631
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.147863
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.148237
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.148428
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.148763
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.148913
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.149177
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.149303
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.149411
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.149555
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.149786
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150026
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150198
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150351
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150682
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150762
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.150834
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.151288
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.151487
# 최적화 완료
# Epoch: 0002 Avg. cost = 0.151615
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.000300
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.000536
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.000689
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.000861
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.001250
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.001560
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.001757
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.001915
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002199
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002235
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002446
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002586
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002760
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.002897
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.003005
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.003279
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.003446
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.003551
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.003675
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004079
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004129
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004368
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004454
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004561
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.004808
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005027
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005214
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005385
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005431
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005605
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005738
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.005829
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006054
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006168
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006442
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006632
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006784
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.006857
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.007049
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.007255
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.007769
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.008021
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.008180
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.008583
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.008813
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.008983
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.009115
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.009203
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.009711
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.009979
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.010164
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.010359
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.010563
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.010759
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.010810
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011092
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011236
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011485
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011672
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011859
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.011985
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.012134
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.012378
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.012482
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.012678
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.012886
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.013042
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.013249
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.013287
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.013469
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.013707
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.014065
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.014356
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.014485
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.014662
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.014976
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.015146
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.015275
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.015373
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.015429
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.015780
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.016170
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.016408
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.016647
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.016735
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.016925
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.017276
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.017445
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.017775
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018136
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018309
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018352
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018484
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018615
# 최적화 완료
# Epoch: 0003 Avg. cost = 0.018727
# ...
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019292
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019467
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019512
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019569
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019626
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019650
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019682
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019689
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019778
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019814
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019913
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.019961
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020111
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020138
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020323
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020346
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020439
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020465
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020488
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020535
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020556
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020646
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020697
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020804
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020825
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020909
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.020991
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021048
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021074
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021109
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021148
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021231
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021254
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021283
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021317
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021368
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021418
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021483
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021570
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021607
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021693
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021703
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021763
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021777
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.021940
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022005
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022031
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022069
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022080
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022083
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022138
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022189
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022275
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022314
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022460
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022490
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022516
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022527
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022553
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022664
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022683
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022700
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.022858
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023109
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023181
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023224
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023269
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023282
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023288
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023316
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023513
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023611
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023674
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023723
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023760
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023786
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023812
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023830
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.023887
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024012
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024092
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024175
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024190
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024205
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024403
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024490
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024557
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024681
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024734
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024806
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024811
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024933
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.024976
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025070
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025086
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025133
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025175
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025360
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025486
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025543
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025623
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025657
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025716
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025779
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025797
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025896
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.025953
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026041
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026079
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026104
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026168
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026269
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026290
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026328
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026414
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026513
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026528
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026578
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026667
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026778
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026923
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.026969
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027015
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027105
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027163
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027219
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027287
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027453
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027557
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027595
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027623
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027654
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027696
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027756
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027806
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027874
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.027887
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028002
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028083
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028122
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028240
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028305
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028371
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028436
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028477
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028612
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028631
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028673
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028693
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028730
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028799
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028849
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028862
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028924
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028960
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.028997
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029085
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029180
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029196
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029233
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029267
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029299
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029359
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029423
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029499
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029630
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029935
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.029973
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030043
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030099
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030184
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030327
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030370
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030385
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030410
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030443
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030534
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030564
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030605
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.030821
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031043
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031053
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031078
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031255
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031289
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031302
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031336
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031376
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031485
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031532
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031607
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031664
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031725
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031797
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031880
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031918
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031958
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.031992
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032104
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032155
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032186
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032220
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032236
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032263
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032438
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032552
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032637
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032779
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032864
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032920
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.032984
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033099
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033318
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033345
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033361
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033379
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033391
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033440
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033662
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033724
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033757
# 최적화 완료
# Epoch: 0007 Avg. cost = 0.033853
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000107
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000258
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000289
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000323
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000408
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000427
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000451
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000569
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000601
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000641
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000673
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000859
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000887
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000960
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000974
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.000983
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001004
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001033
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001055
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001089
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001200
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001228
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001236
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001275
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001301
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001320
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001546
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001564
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001593
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001641
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001658
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001678
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001743
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001776
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001800
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001812
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001858
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001876
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001906
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001977
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.001987
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002022
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002051
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002052
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002075
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002097
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002125
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002173
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002203
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002240
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002247
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002259
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002278
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002287
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002309
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002361
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002411
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002472
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002494
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002512
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002576
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002599
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002623
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002755
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002806
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002812
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002828
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002843
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002936
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.002950
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003023
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003032
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003090
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003111
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003142
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003150
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003243
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003250
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003264
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003300
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003345
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003372
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003400
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003420
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003426
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003442
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003471
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003502
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003520
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003564
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003583
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003623
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003695
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003731
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003747
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003768
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003906
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003935
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003963
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.003992
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004000
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004027
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004078
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004086
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004135
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004263
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004356
# 최적화 완료
# Epoch: 0008 Avg. cost = 0.004373
# 최적화 완료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b0ccfd92d0b7> in <module>()
#      39
#      40     _, cost_val = sess.run([optimizer, cost],
# ---> 41         feed_dict = {X: batch_xs, Y:batch_ys})
#      42     total_cost+=cost_val
#      43
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
